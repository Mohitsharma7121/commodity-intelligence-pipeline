# %%
# !python scripts/data_ingestion.py
# Out:
# ingestion complete
# C:\Users\Mahasar Maa\commodity-intelligence-pipeline\scripts\data_ingestion.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2["date"] = pd.to_datetime(df2["date"], errors="coerce")

# %%
# !python scripts/data_cleaning.py
# Out:
# cleaning complete

# %%
# !python scripts/data_validation.py
# Out:
# Missing values:
#  commodity    0
# date         0
# price        0
# region       0
# source       0
# dtype: int64
#
# Duplicates: 0
#
# Date type: object
#
# Price summary:
#  count    10733.000000
# mean       943.206272
# std        820.015238
# min         80.000000
# 25%        407.000000
# 50%        707.000000
# 75%       1211.000000
# max       6400.000000
# Name: price, dtype: float64
#
# validation complete

# %%
# !python scripts/feature_engineering.py
# Out:
# feature engineering complete

# %%
# !python scripts/signal_generation.py
# Out:
# signal generation complete

# %%
# !python scripts/visualization.py
# Out:
# visualization created
